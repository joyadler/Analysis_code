# %% [markdown]
# ## Change values for analysis based on the cell
# ### Baseline
# #### Change first and last sweep number for each cell based off of when the cell got stable

# %%
pre_drug_first_sweep = 11
pre_drug_last_sweep = 25

# %% [markdown]
# ### Drug wash on

# %%
wash_on_first_sweep = 61
wash_on_last_sweep = 75

# %% [markdown]
# ### Plus APV

# %%
APV_first_sweep = 85
APV_last_sweep = 90

# %% [markdown]
# ### Import packages you want

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read in Files

# %%
data = loadmat("/Users/joyadler/Desktop/FordLab/RawData/20221017_005.mat")
print("total sweeps: " + str(len(data)))
# Out:
# total sweeps: 94

# %%
for i in range(len(data)):
    first_sweep_key = list(data.keys())[i]
    first_value = data[first_sweep_key]

    print(first_sweep_key)
    print(first_value)
    print(' ')
# Out:
# __header__
# b'MATLAB 5.0 MAT-file, Platform: MACOSX, Created on: Thu Aug 3 2023  09:20:12\x002\x00/\x002\x000\x002\x002\x001\x000\x001\x007\x00_\x000\x000\x005\x00.\x00m\x00a\x00t\x000\x000'
#
# __version__
# 1.0
#
# __globals__
# []
#
# c001_Time N
# [[1.0000e-04 2.0000e-04 3.0000e-04 ... 1.9998e+00 1.9999e+00 2.0000e+00]]
#
# c002_Current_Amp1p1
# [[-1.0633125e-11 -9.8306250e-12 -1.4110625e-11 ... -2.0664375e-11
#   -3.3504375e-11 -1.1034375e-11]]
#
# c003_Current_Amp1p1
# [[-2.7418750e-11 -2.4275625e-11 -3.2434375e-11 ... -5.1426875e-11
#   -5.2028750e-11 -6.1859375e-11]]
#
# c004_Current_Amp1p1
# [[-7.29606250e-11 -6.48018750e-11 -6.70756250e-11 ... -1.04391875e-10
#   -1.05996875e-10 -9.48287500e-11]]
#
# c005_Current_Amp1p1
# [[-8.59343750e-11 -8.03168750e-11 -8.94118750e-11 ... -1.00580000e-10
#   -1.09474375e-10 -9.80387500e-11]]
#
# c006_Current_Amp1p1
# [[-1.50803125e-10 -1.46255625e-10 -1.41173125e-10 ... -1.35823125e-10
#   -1.47593125e-10 -1.40303750e-10]]
#
# c007_Current_Amp1p1
# [[-1.55885625e-10 -1.45854375e-10 -1.53946250e-10 ... -1.61436250e-10
#   -1.70531250e-10 -1.71668125e-10]]
#
# c008_Current_Amp1p1
# [[-1.54280625e-10 -1.46790625e-10 -1.63910625e-10 ... -1.59095625e-10
#   -1.56220000e-10 -1.72871875e-10]]
#
# c009_Current_Amp1p1
# [[-1.76951250e-10 -1.74410000e-10 -1.68993125e-10 ... -1.77887500e-10
#   -1.78690000e-10 -1.74276250e-10]]
#
# c010_Current_Amp1p1
# [[-1.63776875e-10 -1.72270000e-10 -1.64579375e-10 ... -1.78422500e-10
#   -1.93870625e-10 -1.95743125e-10]]
#
# c011_Current_Amp1p1
# [[-2.02230000e-10 -1.95542500e-10 -1.97749375e-10 ... -1.91797500e-10
#   -1.86848750e-10 -2.05373125e-10]]
#
# c012_Current_Amp1p1
# [[-1.81632500e-10 -1.85043125e-10 -1.91329375e-10 ... -1.93736875e-10
#   -1.97481875e-10 -1.92533125e-10]]
#
#   -6.0990000e-11 -6.3464375e-11]]
#
# c086_Current_Amp1p1
# [[-5.3433125e-11 -5.2430000e-11 -4.8751875e-11 ... -6.2193750e-11
#   -6.2260625e-11 -5.7445625e-11]]
#
# c087_Current_Amp1p1
# [[-4.4940000e-11 -4.6210625e-11 -5.0290000e-11 ... -5.4570000e-11
#   -5.0891875e-11 -5.0223125e-11]]
#
# c088_Current_Amp1p1
# [[-4.9420625e-11 -5.4503125e-11 -4.6946250e-11 ... -5.3098750e-11
#   -4.9153125e-11 -5.0156250e-11]]
#
# c089_Current_Amp1p1
# [[-4.0927500e-11 -3.9590000e-11 -4.6010000e-11 ... -5.3700625e-11
#   -5.1092500e-11 -4.8150000e-11]]
#
# c090_Current_Amp1p1
# [[-4.8150000e-11 -5.3098750e-11 -5.1694375e-11 ... -5.8850000e-11
#   -5.0891875e-11 -4.7681875e-11]]
#
# c091_Current_Amp1p1
# [[-5.3500000e-11 -4.8751875e-11 -4.8350625e-11 ... -5.1092500e-11
#   -5.0089375e-11 -4.9688125e-11]]

# %% [markdown]
# ## Clean up data and get rid of keys

# %%
new_data = data.copy()  # Create a copy of the original dictionary

for i in range(4):  # Remove the first three keys from the copy
    first_sweep_key = list(new_data.keys())[0]
    new_data.pop(first_sweep_key)

for i in range(len(new_data.keys())):  
    first_sweep_key = list(new_data.keys())[i]
    first_value = new_data[first_sweep_key]

    print(first_sweep_key)
    print(first_value)
    print(' ')

#pA = np.array(new_data).flatten()
#new_data_df = pd.DataFrame(new_data)
#new_data_df.to_csv('/Users/joyadler/Desktop/df/data.csv')
# Out:
# c002_Current_Amp1p1
# [[-1.0633125e-11 -9.8306250e-12 -1.4110625e-11 ... -2.0664375e-11
#   -3.3504375e-11 -1.1034375e-11]]
#
# c003_Current_Amp1p1
# [[-2.7418750e-11 -2.4275625e-11 -3.2434375e-11 ... -5.1426875e-11
#   -5.2028750e-11 -6.1859375e-11]]
#
# c004_Current_Amp1p1
# [[-7.29606250e-11 -6.48018750e-11 -6.70756250e-11 ... -1.04391875e-10
#   -1.05996875e-10 -9.48287500e-11]]
#
# c005_Current_Amp1p1
# [[-8.59343750e-11 -8.03168750e-11 -8.94118750e-11 ... -1.00580000e-10
#   -1.09474375e-10 -9.80387500e-11]]
#
# c006_Current_Amp1p1
# [[-1.50803125e-10 -1.46255625e-10 -1.41173125e-10 ... -1.35823125e-10
#   -1.47593125e-10 -1.40303750e-10]]
#
# c007_Current_Amp1p1
# [[-1.55885625e-10 -1.45854375e-10 -1.53946250e-10 ... -1.61436250e-10
#   -1.70531250e-10 -1.71668125e-10]]
#
# c008_Current_Amp1p1
# [[-1.54280625e-10 -1.46790625e-10 -1.63910625e-10 ... -1.59095625e-10
#   -1.56220000e-10 -1.72871875e-10]]
#
# c009_Current_Amp1p1
# [[-1.76951250e-10 -1.74410000e-10 -1.68993125e-10 ... -1.77887500e-10
#   -1.78690000e-10 -1.74276250e-10]]
#
# c010_Current_Amp1p1
# [[-1.63776875e-10 -1.72270000e-10 -1.64579375e-10 ... -1.78422500e-10
#   -6.8814375e-11 -6.2929375e-11]]
#
# c084_Current_Amp1p1
# [[-5.7445625e-11 -5.8716250e-11 -5.5439375e-11 ... -6.2661875e-11
#   -6.9750625e-11 -5.7780000e-11]]
#
# c085_Current_Amp1p1
# [[-5.4770625e-11 -4.8083125e-11 -4.7414375e-11 ... -6.0722500e-11
#   -6.0990000e-11 -6.3464375e-11]]
#
# c086_Current_Amp1p1
# [[-5.3433125e-11 -5.2430000e-11 -4.8751875e-11 ... -6.2193750e-11
#   -6.2260625e-11 -5.7445625e-11]]
#
# c087_Current_Amp1p1
# [[-4.4940000e-11 -4.6210625e-11 -5.0290000e-11 ... -5.4570000e-11
#   -5.0891875e-11 -5.0223125e-11]]
#
# c088_Current_Amp1p1
# [[-4.9420625e-11 -5.4503125e-11 -4.6946250e-11 ... -5.3098750e-11
#   -4.9153125e-11 -5.0156250e-11]]
#
# c089_Current_Amp1p1
# [[-4.0927500e-11 -3.9590000e-11 -4.6010000e-11 ... -5.3700625e-11
#   -5.1092500e-11 -4.8150000e-11]]
#
# c090_Current_Amp1p1
# [[-4.8150000e-11 -5.3098750e-11 -5.1694375e-11 ... -5.8850000e-11
#   -5.0891875e-11 -4.7681875e-11]]
#
# c091_Current_Amp1p1
# [[-5.3500000e-11 -4.8751875e-11 -4.8350625e-11 ... -5.1092500e-11
#   -5.0089375e-11 -4.9688125e-11]]

# %% [markdown]
# ## Convert the sweep number to minutes to graph changes in the amplitude of response over time

# %%
# Create a new dictionary to store the correlated data
time_correlate = {}

# Calculate the time in minutes for each sweep and add it to the new dictionary
for i, sweep_key in enumerate(new_data.keys()):
    sweep_time_minutes = i * 0.3333  # Each sweep occurs every 20 seconds (0.3333 minutes)
    time_correlate[sweep_time_minutes] = new_data[sweep_key]

    print("Time (minutes):", sweep_time_minutes)
    print("Sweep data:", time_correlate[sweep_time_minutes])
    print(' ')

# The 'time_correlate' dictionary now contains the sweeps correlated to their respective time in minutes
# Out:
# Time (minutes): 0.0
# Sweep data: [[-1.0633125e-11 -9.8306250e-12 -1.4110625e-11 ... -2.0664375e-11
#   -3.3504375e-11 -1.1034375e-11]]
#
# Time (minutes): 0.3333
# Sweep data: [[-2.7418750e-11 -2.4275625e-11 -3.2434375e-11 ... -5.1426875e-11
#   -5.2028750e-11 -6.1859375e-11]]
#
# Time (minutes): 0.6666
# Sweep data: [[-7.29606250e-11 -6.48018750e-11 -6.70756250e-11 ... -1.04391875e-10
#   -1.05996875e-10 -9.48287500e-11]]
#
# Time (minutes): 0.9999
# Sweep data: [[-8.59343750e-11 -8.03168750e-11 -8.94118750e-11 ... -1.00580000e-10
#   -1.09474375e-10 -9.80387500e-11]]
#
# Time (minutes): 1.3332
# Sweep data: [[-1.50803125e-10 -1.46255625e-10 -1.41173125e-10 ... -1.35823125e-10
#   -1.47593125e-10 -1.40303750e-10]]
#
# Time (minutes): 1.6664999999999999
# Sweep data: [[-1.55885625e-10 -1.45854375e-10 -1.53946250e-10 ... -1.61436250e-10
#   -1.70531250e-10 -1.71668125e-10]]
#
# Time (minutes): 1.9998
# Sweep data: [[-1.54280625e-10 -1.46790625e-10 -1.63910625e-10 ... -1.59095625e-10
#   -1.56220000e-10 -1.72871875e-10]]
#
# Time (minutes): 2.3331
# Sweep data: [[-1.76951250e-10 -1.74410000e-10 -1.68993125e-10 ... -1.77887500e-10
#   -1.78690000e-10 -1.74276250e-10]]
#
# Time (minutes): 2.6664
# Sweep data: [[-1.63776875e-10 -1.72270000e-10 -1.64579375e-10 ... -1.78422500e-10
#   -1.93870625e-10 -1.95743125e-10]]
#
# Time (minutes): 2.9997
# Sweep data: [[-2.02230000e-10 -1.95542500e-10 -1.97749375e-10 ... -1.91797500e-10
#   -1.86848750e-10 -2.05373125e-10]]
#
# Time (minutes): 3.3329999999999997
# Sweep data: [[-1.81632500e-10 -1.85043125e-10 -1.91329375e-10 ... -1.93736875e-10
#   -1.97481875e-10 -1.92533125e-10]]
#
# Time (minutes): 3.6662999999999997
# Sweep data: [[-1.95810000e-10 -1.76817500e-10 -1.83571875e-10 ... -2.04971875e-10
#   -1.90058750e-10 -1.95208125e-10]]
#
# Time (minutes): 3.9996
# Sweep data: [[-1.83438125e-10 -1.75346250e-10 -1.75948125e-10 ... -1.73340000e-10
#   -1.72270000e-10 -1.77486250e-10]]
#
# Time (minutes): 4.3328999999999995
# Sweep data: [[-1.87450625e-10 -1.89456875e-10 -1.96144375e-10 ... -1.67521875e-10
#   -1.89122500e-10 -1.86180000e-10]]
#
# Time (minutes): 4.6662
# Sweep data: [[-1.53478125e-10 -1.52073750e-10 -1.49933750e-10 ... -1.70531250e-10
#   -1.76215625e-10 -1.70531250e-10]]
#
# Time (minutes): 4.999499999999999
# Sweep data: [[-1.72604375e-10 -1.60366250e-10 -1.69929375e-10 ... -1.58828125e-10
#   -1.57490625e-10 -1.53879375e-10]]
#
# Time (minutes): 5.3328
# Sweep data: [[-1.43380000e-10 -1.47325625e-10 -1.45453125e-10 ... -1.59296250e-10
#   -1.59430000e-10 -1.72671250e-10]]
#
# Time (minutes): 5.6661
# Sweep data: [[-1.61101875e-10 -1.51806250e-10 -1.63175000e-10 ... -1.52408125e-10
#   -1.51940000e-10 -1.54815625e-10]]
#
# Time (minutes): 5.9994
# Sweep data: [[-1.42644375e-10 -1.46121875e-10 -1.43246250e-10 ... -1.48529375e-10
#   -1.57156250e-10 -1.56955625e-10]]
#
# Time (minutes): 6.3327
# Sweep data: [[-1.59028750e-10 -1.55618125e-10 -1.54347500e-10 ... -1.66184375e-10
#   -1.72604375e-10 -1.67388125e-10]]
#
# Time (minutes): 6.6659999999999995
# Sweep data: [[-1.49866875e-10 -1.55150000e-10 -1.46188750e-10 ... -1.64044375e-10
#   -1.73005625e-10 -1.72002500e-10]]
#
# Time (minutes): 6.9993
# Sweep data: [[-1.38899375e-10 -1.33215000e-10 -1.27463750e-10 ... -2.06510000e-10
#   -1.97481875e-10 -2.02029375e-10]]
#
# Time (minutes): 7.332599999999999
# Sweep data: [[-1.26393750e-10 -1.35020625e-10 -1.22381250e-10 ... -1.50870000e-10
#   -1.68993125e-10 -1.59764375e-10]]
#
# Time (minutes): 7.6659
# Sweep data: [[-1.25457500e-10 -1.22515000e-10 -1.25457500e-10 ... -1.41440625e-10
#   -1.41240000e-10 -1.40705000e-10]]
#
# Time (minutes): 7.9992
# Sweep data: [[-1.45185625e-10 -1.40705000e-10 -1.42176250e-10 ... -1.31743750e-10
#   -1.43513750e-10 -1.41106250e-10]]
#
# Time (minutes): 8.3325
# Sweep data: [[-1.24120000e-10 -1.11079375e-10 -1.14021875e-10 ... -1.70130000e-10
#   -1.73941875e-10 -1.74410000e-10]]
#
# Time (minutes): 8.665799999999999
# Sweep data: [[-1.37026875e-10 -1.31275625e-10 -1.35421875e-10 ... -1.42310000e-10
#   -1.45854375e-10 -1.43781250e-10]]
#
# Time (minutes): 8.9991
# Sweep data: [[-1.56821875e-10 -1.56821875e-10 -1.62840625e-10 ... -1.46590000e-10
#   -1.52207500e-10 -1.40303750e-10]]
#
# Time (minutes): 9.3324
# Sweep data: [[-1.00580000e-10 -1.11881875e-10 -9.99112500e-11 ... -1.22983125e-10
#   -1.22849375e-10 -1.23852500e-10]]
#
# Time (minutes): 9.6657
# Sweep data: [[-1.00513125e-10 -8.91443750e-11 -9.81056250e-11 ... -1.35689375e-10
#   -1.41775000e-10 -1.34218125e-10]]
#
# Time (minutes): 9.998999999999999
# Sweep data: [[-9.89081250e-11 -1.10210000e-10 -1.02853750e-10 ... -1.47726875e-10
#   -1.52274375e-10 -1.45586875e-10]]
#
# Time (minutes): 10.3323
# Sweep data: [[-1.06063750e-10 -1.08003125e-10 -1.05060625e-10 ... -1.34686250e-10
#   -1.18368750e-10 -1.30005000e-10]]
#
# Time (minutes): 10.6656
# Sweep data: [[-9.28893750e-11 -9.19531250e-11 -8.74725000e-11 ... -1.26260000e-10
#   -1.18502500e-10 -1.12684375e-10]]
#
# Time (minutes): 10.998899999999999
# Sweep data: [[-7.87787500e-11 -8.29918750e-11 -8.46637500e-11 ... -1.10878750e-10
#   -1.08671875e-10 -1.16429375e-10]]
#
# Time (minutes): 11.3322
# Sweep data: [[-1.02786875e-10 -1.10878750e-10 -1.05395000e-10 ... -1.09808750e-10
#   -1.07133750e-10 -1.09875625e-10]]
#
# Time (minutes): 11.6655
# Sweep data: [[-1.02519375e-10 -9.79050000e-11 -9.52300000e-11 ... -1.06130625e-10
#   -1.15626875e-10 -1.09407500e-10]]
#
# Time (minutes): 11.9988
# Sweep data: [[-1.09340625e-10 -1.09006250e-10 -1.03656250e-10 ... -1.24588125e-10
#   -1.28400000e-10 -1.19037500e-10]]
#
# Time (minutes): 12.332099999999999
# Sweep data: [[-8.81412500e-11 -9.56981250e-11 -8.94118750e-11 ... -9.56312500e-11
#   -1.04525625e-10 -1.05595625e-10]]
#
# Time (minutes): 12.6654
# Sweep data: [[-1.10945625e-10 -1.18368750e-10 -1.14556875e-10 ... -1.13553750e-10
#   -1.08738750e-10 -1.07936250e-10]]
#
# Time (minutes): 12.9987
# Sweep data: [[-6.5270000e-11 -5.5506250e-11 -6.5336875e-11 ... -8.4396250e-11
#   -9.6968750e-11 -8.8007500e-11]]
#
# Time (minutes): 13.331999999999999
# Sweep data: [[-7.0686875e-11 -7.0218750e-11 -7.4164375e-11 ... -8.8141250e-11
#   -8.7004375e-11 -9.3491250e-11]]
#
# Time (minutes): 13.6653
# Sweep data: [[-6.9148750e-11 -6.8747500e-11 -6.9550000e-11 ... -8.7271875e-11
#   -8.6937500e-11 -9.2889375e-11]]
#
# Time (minutes): 13.9986
# Sweep data: [[-8.5800625e-11 -8.9612500e-11 -8.6870625e-11 ... -7.6438125e-11
#   -7.2960625e-11 -7.1890625e-11]]
#
# Time (minutes): 14.3319
# Sweep data: [[-8.0651250e-11 -7.1422500e-11 -7.5769375e-11 ... -8.2390000e-11
#   -7.9648125e-11 -7.9781875e-11]]
#
# Time (minutes): 14.665199999999999
# Sweep data: [[-6.3196875e-11 -6.6674375e-11 -6.7410000e-11 ... -9.4293750e-11
#   -8.6736875e-11 -8.9010625e-11]]
#
# Time (minutes): 14.9985
# Sweep data: [[-7.1021250e-11 -6.0990000e-11 -7.3228125e-11 ... -6.6406875e-11
#   -6.7008750e-11 -6.3464375e-11]]
#
# Time (minutes): 15.3318
# Sweep data: [[-9.3758750e-11 -1.0165000e-10 -9.5029375e-11 ... -7.8243750e-11
#   -7.5033750e-11 -8.2456875e-11]]
#
# Time (minutes): 15.665099999999999
# Sweep data: [[-7.4632500e-11 -7.3896875e-11 -7.8043125e-11 ... -9.6500625e-11
#   -9.5230000e-11 -9.9376250e-11]]
#
# Time (minutes): 15.9984
# Sweep data: [[-6.2060000e-11 -5.8850000e-11 -6.3798750e-11 ... -8.0517500e-11
#   -7.6571875e-11 -7.9514375e-11]]
#
# Time (minutes): 16.331699999999998
# Sweep data: [[-7.8444375e-11 -7.6304375e-11 -7.0486250e-11 ... -9.0147500e-11
#   -8.2256250e-11 -8.3727500e-11]]
#
# Time (minutes): 16.665
# Sweep data: [[-6.5002500e-11 -5.7846875e-11 -6.4133125e-11 ... -6.7878125e-11
#   -6.3932500e-11 -7.1556250e-11]]
#
# Time (minutes): 16.9983
# Sweep data: [[-5.2296250e-11 -5.2630625e-11 -6.6674375e-11 ... -6.4266875e-11
#   -6.1525000e-11 -6.7610625e-11]]
#
# Time (minutes): 17.331599999999998
# Sweep data: [[-7.7441250e-11 -7.5702500e-11 -7.1221875e-11 ... -9.4628125e-11
#   -9.9510000e-11 -9.3758750e-11]]
#
# Time (minutes): 17.6649
# Sweep data: [[-5.6041250e-11 -6.3731875e-11 -5.5171875e-11 ... -8.7405625e-11
#   -8.8074375e-11 -8.2724375e-11]]
#
# Time (minutes): 17.9982
# Sweep data: [[-6.1056875e-11 -6.4333750e-11 -6.6941875e-11 ... -6.9550000e-11
#   -6.7075625e-11 -6.1725625e-11]]
#
# Time (minutes): 18.3315
# Sweep data: [[-5.8248125e-11 -6.3130000e-11 -6.2060000e-11 ... -7.1489375e-11
#   -8.3794375e-11 -7.3495625e-11]]
#
# Time (minutes): 18.6648
# Sweep data: [[-6.8881250e-11 -6.4735000e-11 -6.5671250e-11 ... -9.0013750e-11
#   -8.9545625e-11 -8.7071250e-11]]
#
# Time (minutes): 18.9981
# Sweep data: [[-7.0686875e-11 -8.2791250e-11 -7.6438125e-11 ... -9.2287500e-11
#   -8.8475625e-11 -9.1351250e-11]]
#
# Time (minutes): 19.3314
# Sweep data: [[-8.13200000e-11 -7.66387500e-11 -7.33618750e-11 ... -9.42937500e-11
#   -1.03455625e-10 -9.96437500e-11]]
#
# Time (minutes): 19.6647
# Sweep data: [[-7.61037500e-11 -8.32593750e-11 -8.67368750e-11 ... -9.17525000e-11
#   -9.81056250e-11 -1.01984375e-10]]
#
# Time (minutes): 19.997999999999998
# Sweep data: [[-8.4128750e-11 -8.6402500e-11 -7.9915625e-11 ... -7.8778750e-11
#   -7.1088125e-11 -7.0419375e-11]]
#
# Time (minutes): 20.3313
# Sweep data: [[-6.8546875e-11 -6.5069375e-11 -5.9920000e-11 ... -6.4868750e-11
#   -6.5203125e-11 -7.1623125e-11]]
#
# Time (minutes): 20.6646
# Sweep data: [[-9.2421250e-11 -9.2488125e-11 -9.8774375e-11 ... -8.8475625e-11
#   -8.9144375e-11 -8.7405625e-11]]
#
# Time (minutes): 20.997899999999998
# Sweep data: [[-8.0718125e-11 -7.9380625e-11 -8.5466250e-11 ... -8.6603125e-11
#   -9.0481875e-11 -8.6402500e-11]]
#
# Time (minutes): 21.3312
# Sweep data: [[-9.70356250e-11 -9.72362500e-11 -1.00580000e-10 ... -1.02920625e-10
#   -9.63000000e-11 -1.09273750e-10]]
#
# Time (minutes): 21.6645
# Sweep data: [[-8.88768750e-11 -9.35581250e-11 -9.99112500e-11 ... -1.08270625e-10
#   -1.12951875e-10 -1.11681250e-10]]
#
# Time (minutes): 21.997799999999998
# Sweep data: [[-1.02786875e-10 -1.09474375e-10 -1.10611250e-10 ... -1.02118125e-10
#   -9.97775000e-11 -9.95768750e-11]]
#
# Time (minutes): 22.3311
# Sweep data: [[-8.20556250e-11 -8.31256250e-11 -8.45300000e-11 ... -1.10410625e-10
#   -1.15894375e-10 -1.10878750e-10]]
#
# Time (minutes): 22.6644
# Sweep data: [[-1.10544375e-10 -1.09942500e-10 -1.04926875e-10 ... -1.16964375e-10
#   -1.19238125e-10 -1.20910000e-10]]
#
# Time (minutes): 22.9977
# Sweep data: [[-1.10544375e-10 -1.10009375e-10 -1.08136875e-10 ... -1.28266250e-10
#   -1.28199375e-10 -1.37026875e-10]]
#
# Time (minutes): 23.331
# Sweep data: [[-8.92112500e-11 -9.77043750e-11 -8.35937500e-11 ... -1.38765625e-10
#   -1.31208750e-10 -1.33549375e-10]]
#
# Time (minutes): 23.664299999999997
# Sweep data: [[-1.03656250e-10 -1.05930000e-10 -1.06866250e-10 ... -1.32345625e-10
#   -1.32011250e-10 -1.30071875e-10]]
#
# Time (minutes): 23.9976
# Sweep data: [[-1.00914375e-10 -9.48956250e-11 -1.01650000e-10 ... -1.33215000e-10
#   -1.29403125e-10 -1.30339375e-10]]
#
# Time (minutes): 24.3309
# Sweep data: [[-1.03054375e-10 -1.05729375e-10 -1.01382500e-10 ... -1.53611875e-10
#   -1.51940000e-10 -1.53010000e-10]]
#
# Time (minutes): 24.664199999999997
# Sweep data: [[-1.01315625e-10 -9.25550000e-11 -9.95100000e-11 ... -1.15894375e-10
#   -1.15426250e-10 -1.12550625e-10]]
#
# Time (minutes): 24.9975
# Sweep data: [[-9.98443750e-11 -1.09073125e-10 -9.98443750e-11 ... -1.20776250e-10
#   -1.22648750e-10 -1.21110625e-10]]
#
# Time (minutes): 25.3308
# Sweep data: [[-8.37943750e-11 -7.74412500e-11 -8.74056250e-11 ... -1.24855625e-10
#   -1.30005000e-10 -1.26126250e-10]]
#
# Time (minutes): 25.664099999999998
# Sweep data: [[-7.85112500e-11 -9.37587500e-11 -8.25906250e-11 ... -1.25791875e-10
#   -1.18034375e-10 -1.25190000e-10]]
#
# Time (minutes): 25.9974
# Sweep data: [[-1.17432500e-10 -1.17766875e-10 -1.17098125e-10 ... -1.22113750e-10
#   -1.27129375e-10 -1.23919375e-10]]
#
# Time (minutes): 26.3307
# Sweep data: [[-7.4231250e-11 -6.7075625e-11 -7.2158125e-11 ... -7.3361875e-11
#   -7.6906250e-11 -6.6139375e-11]]
#
# Time (minutes): 26.663999999999998
# Sweep data: [[-7.2893750e-11 -7.1221875e-11 -7.6170625e-11 ... -8.4797500e-11
#   -7.9180000e-11 -7.2091250e-11]]
#
# Time (minutes): 26.9973
# Sweep data: [[-5.4971250e-11 -5.4168750e-11 -5.2028750e-11 ... -6.3130000e-11
#   -6.8814375e-11 -6.2929375e-11]]
#
# Time (minutes): 27.3306
# Sweep data: [[-5.7445625e-11 -5.8716250e-11 -5.5439375e-11 ... -6.2661875e-11
#   -6.9750625e-11 -5.7780000e-11]]
#
# Time (minutes): 27.663899999999998
# Sweep data: [[-5.4770625e-11 -4.8083125e-11 -4.7414375e-11 ... -6.0722500e-11
#   -6.0990000e-11 -6.3464375e-11]]
#
# Time (minutes): 27.9972
# Sweep data: [[-5.3433125e-11 -5.2430000e-11 -4.8751875e-11 ... -6.2193750e-11
#   -6.2260625e-11 -5.7445625e-11]]
#
# Time (minutes): 28.330499999999997
# Sweep data: [[-4.4940000e-11 -4.6210625e-11 -5.0290000e-11 ... -5.4570000e-11
#   -5.0891875e-11 -5.0223125e-11]]
#
# Time (minutes): 28.6638
# Sweep data: [[-4.9420625e-11 -5.4503125e-11 -4.6946250e-11 ... -5.3098750e-11
#   -4.9153125e-11 -5.0156250e-11]]
#
# Time (minutes): 28.9971
# Sweep data: [[-4.0927500e-11 -3.9590000e-11 -4.6010000e-11 ... -5.3700625e-11
#   -5.1092500e-11 -4.8150000e-11]]
#
# Time (minutes): 29.330399999999997
# Sweep data: [[-4.8150000e-11 -5.3098750e-11 -5.1694375e-11 ... -5.8850000e-11
#   -5.0891875e-11 -4.7681875e-11]]
#
# Time (minutes): 29.6637
# Sweep data: [[-5.3500000e-11 -4.8751875e-11 -4.8350625e-11 ... -5.1092500e-11
#   -5.0089375e-11 -4.9688125e-11]]

# %% [markdown]
# ## Plot all traces

# %%
plt.figure(figsize=(10, 6))  # Create a new figure to look at your sweeps


# Plot pA data over time for each trial
for trial_name, pA in list(new_data.items()):
    pA = np.array(pA).flatten()  # flatten the array becuase it is 2D
    times = np.linspace(0, len(pA)/10, len(pA))  # create a time array
    plt.plot(times, pA * 1e12)  # multiplying by 1e12 to convert the unit from A to pA
   # break  # Break the loop after the first iteration
    

#plt.ylim(-800, 800) # adjust data range in pA
#plt.xlim(1250, 1500) # adjust this according to your data range in pA

plt.xlabel('Time (ms)')  # Add a label to the x-axis
plt.ylabel('Picoamps (pA)')  # Add a label to the y-axis
plt.title('Pre Drug Baseline')  # Add a title

plt.grid(True)  # Show grid lines (optional)

plt.show()  # Display the plot

# %% [markdown]
# ## Make function to graph sweeps

# %%
# Changed function to make the sweep numbers an input you can change 

def plot_sweeps(new_data, start_time, end_time, initial_sweep, final_sweep): 
    plt.figure(figsize=(10, 6))

    # Plot pA data over time for each trial
    for trial_name, pA in list(new_data.items())[initial_sweep:final_sweep]:
        pA = np.array(pA).flatten()  # flatten the array becuase it is 2D
        times = np.linspace(0, len(pA)/10, len(pA))  # create a time array
        plt.plot(times, pA * 1e12)  # multiplying by 1e12 to convert the unit from A to pA
        #break  # Break the loop after the first iteration
        
    #look only at specific time points for your base amp pre stim
    plt.ylim(-1000, 800) # adjust data range in pA
    plt.xlim(start_time, end_time) # adjust this according to your data range in pA


    plt.xlabel('Time (ms)')  # Add a label to the x-axis
    plt.ylabel('Picoamps (pA)')  # Add a label to the y-axis
    plt.title('Base amp')  # Add a title

    plt.grid(True)

# %%
plot_sweeps(new_data, 55,100, 10,20)

# %% [markdown]
# ## Make funcitons to find the values for your baseline amplitude
# ### pre_drug

# %%
def calculate_average_baseline_amp(new_data, pre_drug_first_sweep, pre_drug_last_sweep,baseline_window = (550, 1000)): #use these values because you already defined the beginning and end 
    count = 0
    total = np.zeros(baseline_window[1]-baseline_window[0]) #np.zeros lets you fill in as you go from start to end of your set times 
    

    for sweep, value in enumerate(new_data.values()): #enumerate lets you run throgh the list of your keys
        if pre_drug_first_sweep <= sweep <= pre_drug_last_sweep:
            count += 1
            total += value[0][baseline_window[0]:baseline_window[1]] #value[0] becuase you have a nested list, one is the list itself and one is the values
            #print(baseline_window)
          

    
            #to get just the values, you want to index to them
    if count == 0:
        return None  # Return None if there are no data points in the specified time period
    else:
        return total / count

average_baseline_pre_drug = calculate_average_baseline_amp(new_data, pre_drug_first_sweep,pre_drug_last_sweep)
baseline_avg_pre_drug = np.average(average_baseline_pre_drug)
pA_avg_pre_drug = baseline_avg_pre_drug*(10 ** 12)
print(pA_avg_pre_drug)
# Out:
# -157.9849550925926

# %% [markdown]
# ### wash_on baseline

# %%
def calculate_average_baseline_amp_wash_on(new_data, wash_on_first_sweep, wash_on_last_sweep,baseline_window1 = (550, 1000)): #use these values because you already defined the beginning and end 
    count = 0
    total = np.zeros(baseline_window1[1]-baseline_window1[0]) #np.zeros lets you fill in as you go from start to end of your set times 
    

    for sweep, value1 in enumerate(new_data.values()): #enumerate lets you run throgh the list of your keys
        if wash_on_first_sweep <= sweep <= wash_on_last_sweep:
            count += 1
            total += value1[0][baseline_window1[0]:baseline_window1[1]] #value[0] becuase you have a nested list, one is the list itself and one is the values

            # print(value[0][baseline_window[0]:baseline_window[1]])
            #to get just the values, you want to index to them
    if count == 0:
        return None  # Return None if there are no data points in the specified time period
    else:
        return total / count


average_baseline_value_wash_on = calculate_average_baseline_amp_wash_on(new_data, wash_on_first_sweep, wash_on_last_sweep)
# print(average_value) #output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need


baseline_avg_wash_on = np.average(average_baseline_value_wash_on)
pA_avg_wash_on = baseline_avg_wash_on*(10 ** 12)
print(pA_avg_wash_on)
# Out:
# -95.93263333333333

# %% [markdown]
# ### APV Baseline

# %%
def calculate_average_baseline_amp_APV(new_data, APV_first_sweep, APV_last_sweep,baseline_window2 = (550, 1000)): #use these values because you already defined the beginning and end 
    count = 0
    total = np.zeros(baseline_window2[1]-baseline_window2[0]) #np.zeros lets you fill in as you go from start to end of your set times 
    

    for sweep, value in enumerate(new_data.values()): #enumerate lets you run throgh the list of your keys
        if APV_first_sweep <= sweep <= APV_last_sweep:
            count += 1
            total += value[0][baseline_window2[0]:baseline_window2[1]] #value[0] becuase you have a nested list, one is the list itself and one is the values

            # print(value[0][baseline_window[0]:baseline_window[1]])
            #to get just the values, you want to index to them
    if count == 0:
        return None  # Return None if there are no data points in the specified time period
    else:
        return total / count


average_baseline_value_APV = calculate_average_baseline_amp_APV(new_data, APV_first_sweep, APV_last_sweep)
# print(average_value) #output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need


baseline_avg_APV = np.average(average_baseline_value_APV)
pA_avg_APV = baseline_avg_APV*(10 ** 12)
print(pA_avg_APV)
# Out:
# -49.25813361111111

# %% [markdown]
# ## Find values of peak (min) response

# %% [markdown]
# ## Find the min amplitude of first response
# ### pre_drug first peak

# %%
def calculate_average_peak_pre_drug(new_data, pre_drug_first_sweep, pre_drug_last_sweep,peak_window = (100, 150)): #use these values because you already defined the beginning and end 
    count = 0
    total = np.zeros(peak_window[1]-peak_window[0]) #np.zeros lets you fill in as you go from start to end of your set times 
    

    for first_peak, value in enumerate(new_data.values()): #enumerate lets you run throgh the list of your keys
        if pre_drug_first_sweep <= first_peak <= pre_drug_last_sweep:
            count += 1
            total += min(value[0][peak_window[0]:peak_window[1]]) #value[0] becuase you have a nested list, one is the list itself and one is the values
            #to get just the values, you want to index to them

    if count == 0:
        return None  # Return None if there are no data points in the specified time period
    else:
        return total / count

first_peak_pre_drug = calculate_average_first_peak_pre_drug(new_data, pre_drug_first_sweep, pre_drug_last_sweep,peak_window = (100, 150))
# print(average_value) #output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need


first_peak_avg_pre_drug = np.average(first_peak_pre_drug)
pA_first_peak_pre_drug = first_peak_avg_pre_drug*(10 ** 12)
print(pA_first_peak_pre_drug)
# Out:
# -234.32554166666665

# %% [markdown]
# ### pre_drug second peak

# %%
second_peak_pre_drug = calculate_average_peak_pre_drug(new_data, pre_drug_first_sweep, pre_drug_last_sweep,peak_window = (1405, 1450))
# print(average_value) #output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need


second_peak_pre_drug = np.average(second_peak_pre_drug)
pA_second_peak_pre_drug = second_peak_pre_drug*(10 ** 12)
print(pA_second_peak_pre_drug)
# Out:
# -318.95362499999993

# %%
plot_sweeps(new_data, 1405,1450, 61,75)

# %% [markdown]
# ### wash_on first peak

# %%
def calculate_average_peak_wash_on(new_data, wash_on_first_sweep, wash_on_last_sweep, peak_window = (100, 150)): #use these values because you already defined the beginning and end 
    count = 0
    total = np.zeros(peak_window[1]-peak_window[0]) #np.zeros lets you fill in as you go from start to end of your set times 
    

    for first_peak, value in enumerate(new_data.values()): #enumerate lets you run throgh the list of your keys
        if wash_on_first_sweep <= first_peak <= wash_on_last_sweep:
            count += 1
            total += min(value[0][peak_window[0]:peak_window[1]]) #value[0] becuase you have a nested list, one is the list itself and one is the values
            #to get just the values, you want to index to them

    if count == 0:
        return None  # Return None if there are no data points in the specified time period
    else:
        return total / count

first_peak_wash_on = calculate_average_peak_wash_on(new_data, wash_on_first_sweep, wash_on_last_sweep,peak_window = (100, 150))
# print(average_value) #output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need


first_peak_avg_wash_on = np.average(first_peak_wash_on)
pA_first_peak_wash_on = first_peak_avg_wash_on*(10 ** 12)
print(pA_first_peak_wash_on)
# Out:
# -180.69625000000002

# %% [markdown]
# ### wash_on second peak

# %%
average_second_peak_value_wash_on = calculate_average_peak_wash_on(new_data, wash_on_first_sweep, wash_on_last_sweep, peak_window = (1405, 1450))
first_peak_avg_wash_on = np.average(average_first_peak_value_wash_on)
pA_first_peak_wash_on = first_peak_avg_wash_on*(10 ** 12)
print(pA_first_peak_wash_on)
# Out:
# -180.69625000000002

# %% [markdown]
# ### APV first peak

# %%
average_first_peak_value_APV = calculate_average_first_peak(new_data, APV_first_sweep1, APV_last_sweep1)
#output is giving average for each sweep, then you have to take the average of the averages to get the baseline value you need

first_peak_avg_APV = np.average(average_first_peak_value_APV)
pA_first_peak_APV = first_peak_avg_APV*(10 ** 12)
print(pA_first_peak_APV)
# Out:
# -127.63762500000003

# %% [markdown]
# ### APV second peak

# %% [markdown]
# ## then get values of responses

# %%
def calc_first_response_pre_drug(pA_avg_pre_drug, pA_first_peak_pre_drug):
    first_response_pre_drug = pA_avg_pre_drug - pA_first_peak_pre_drug
print(first_response_pre_drug)
# Out:
# 76.34058657407405

# %% [markdown]
# ## Normalize

# %% [markdown]
# ## add series resistance calculation over time

# %%
plot_sweeps(new_data, 0,50, 10, 25)

# %%
# in 4mV step, find peak of down inflection and divide 
# .004/ current response X whatever you need to get it to pA
# 
# input is average of flat part
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       1 # in 4mV step, find peak of down inflection and divide
#       2 # .004/ current response X whatever you need to get it to pA
#       3 #
#       4 # input is average of flat part
# ----> 6 plot_sweeps(new_data, 0,50, 10,90)
#
# NameError: name 'plot_sweeps' is not defined

# %% [markdown]
# ## Export into table
